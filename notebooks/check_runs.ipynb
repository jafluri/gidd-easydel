# %%
import wandb
import pandas as pd

from notebooks.utils import WANDB_PROJECT

# %%
merge_keys = ["batch_size", "lr", "mixing_shift", "layers", "hidden_size", "beta2", "tpu_zone", "tpu_version"]

# %%
def format_command(row):
    # print(row)
    "main_ray.py --batch_size 256 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l16_d1024,noise_mask"
    if not pd.isna(row["command"]) and not pd.isna(row["wandb_id"]):
        print(row["command"])
        if "--resume_wandb_id" in row["command"]:
            return row["command"]
        else:
            return f"{row['command']} --resume_wandb_id {row['wandb_id']}"
    noise_label = {
        -1000.0: "noise_mask",
        -2.0: "noise_low_uniform",
        0.0: "noise_balanced",
        2.0: "noise_high_uniform",
        1000.0: "noise_uniform",
    }.get(row["mixing_shift"], "noise_unknown")
    args = [
        ("--batch_size", int(row["batch_size"])),
        ("--lr", float(row["lr"])),
        ("--max_training_steps", 100000),
        ("--num_layers", int(row["layers"])),
        ("--hidden_size", int(row["hidden_size"])),
        ("--num_attn_heads", int(row["hidden_size"]) // 64 if row["hidden_size"] <= 1024 else row["hidden_size"] // 128),
        ("--max_seq_len", 2048),
        ("--cooldown_steps", 0.0),
        ("--beta2", float(row["beta2"])),
        ("--no-break_on_nan",),
        ("--wandb_name", f"gidd-L{int(row['layers'])}-D{int(row['hidden_size'])}-H{int(row['hidden_size'])//64}-N2048-bs={int(row['batch_size'])}-lr={float(row['lr'])}-{noise_label}"),
        ("--hybrid_mixing_shift", float(row["mixing_shift"])),
        ("--wandb_tags", f"crit_bs_l{int(row['layers'])}_d{int(row['hidden_size'])},{noise_label}"),
    ]
    return "main_ray.py " + " ".join(" ".join(map(str, arg)) for arg in args)

# %%
from datetime import datetime, timezone
from zoneinfo import ZoneInfo

dt_local = datetime(2025, 9, 13, 21, 0, tzinfo=ZoneInfo("Europe/Zurich"))
dt_utc = dt_local.astimezone(timezone.utc)

runs = wandb.Api().runs(
    path=WANDB_PROJECT,
    filters={
        "$and": [
            {"$or": [
                {"tags": "crit_bs_l8_d512"},
                {"tags": "crit_bs_l12_d768"},
                {"tags": "crit_bs_l16_d1024"},
                {"tags": "scaling_laws"},
            ]},
            {"created_at": {"$gte": dt_utc.isoformat()}}
        ],
    },
    order="+created_at",
    per_page=1000,
)
len(runs)
# Out:
# 510

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import subprocess
import re


patterns = {
    "batch_size": re.compile(r"--batch_size (\d+)"),
    "lr": re.compile(r"--lr ([\d.]+)"),
    "layers": re.compile(r"--num_layers (\d+)"),
    "hidden_size": re.compile(r"--hidden_size (\d+)"),
    "beta2": re.compile(r"--beta2 ([\d.]+)"),
    "mixing_shift": re.compile(r"--hybrid_mixing_shift ([\-\d.]+)"),
    "tpu_zone": re.compile(r"TPU_ZONE=([a-z0-9\-]+)"),
    "tpu_version": re.compile(r"TPU_VERSION=([a-z0-9\-]+)"),
    "tpu_count": re.compile(r"TPU_POD_COUNT=(\d+)"),
}

def parse_command(command):
    parsed = {}
    for key, pattern in patterns.items():
        match = pattern.search(command)
        if match:
            val = match.group(1)
            try:
                parsed[key] = float(val) if '.' in val else int(val)
            except ValueError:
                parsed[key] = val
    return parsed

addresses = {
    "asia-northeast1-b": "$RAY_ASIA_NORTHEAST1_B",
    "europe-west4-a": "$RAY_EU_WEST4_A",
    "us-central1-a": "$RAY_US_CENTRAL1_A",
    "us-east1-d": "$RAY_US_EAST1_D",
    "us-east5-a": "$RAY_US_EAST5_A",
    "us-east5-b": "$RAY_US_EAST5_B",
}

# for address in addresses:
#     output = subprocess.run(["zsh", "-lc", f"ray job list --address {address}"], capture_output=True, text=True)
#     print(output)
all_rows = []
with ThreadPoolExecutor(max_workers=len(addresses)) as executor:
    futures = {}
    for tpu_zone, address in addresses.items():
        cmd = f"source ~/.zshrc && ray job list --address {address}"
        futures[executor.submit(subprocess.run, cmd, shell=True, capture_output=True, text=True, executable="/bin/zsh")] = tpu_zone
    for future in as_completed(futures):
        tpu_zone = futures[future]
        output = future.result()
        # print(output)
        lines = output.stdout.splitlines()[1:]
        rows = [parse_command(x) for x in lines if "RUNNING" in x]
        for row in rows:
            row["tpu_zone"] = tpu_zone
            row["is_running"] = True
        all_rows.extend(rows)

running_df = pd.DataFrame(all_rows)
running_df
# Out:
#     batch_size    lr  layers  hidden_size  beta2  mixing_shift tpu_version  \
# 0         1024  2.00       8          512   0.97           0.0     v6e-256
# 1          256  0.50      12          768   0.98       -1000.0      v6e-32
# 2          256  1.00      16         1024   0.98           0.0      v6e-64
# 3          256  0.30      12          768   0.98           2.0      v6e-32
# 4          256  0.30      16         1024   0.98           0.0      v6e-64
# 5          128  0.40      10          640   0.99        1000.0       v6e-8
# 6          128  0.40      20         1536   0.99          -2.0       v6e-8
# 7           32  0.25      10          640   0.99           0.0       v6e-8
# 8          512  0.50       8          512   0.95           0.0      v5p-32
# 9         1024  1.00       8          512   0.97           0.0      v5p-64
# 10         512  0.30       8          512   0.98           2.0      v5p-32
# 11         512  0.30       8          512   0.98          -2.0      v5p-32
# 12        1024  0.80      40         5120   0.95           NaN    v5p-1024
# 13         512  0.30       8          512   0.98       -1000.0      v5p-32
# 14         512  0.50      12          768   0.98           0.0      v5p-64
# 15         512  0.50      32         4096   0.98           NaN     v5p-512
# 16         512  0.50      12          768   0.98          -2.0      v5p-64
# 17         512  0.50      16         1024   0.98       -1000.0      v5p-64
# 18         512  0.50      16         1024   0.98          -2.0      v5p-64
# 19         512  0.50      12          768   0.98       -1000.0      v5p-64
# 20         512  0.50      16         1024   0.98           0.0      v5p-64
# 21         512  0.50      12          768   0.98        1000.0      v5p-64
# 22         512  0.50      12          768   0.98           2.0      v5p-64
# 23         512  0.30       8          512   0.98           0.0      v5p-32
# 24         512  0.50      16         1024   0.98           2.0      v5p-64
# 25         512  0.50      16         1024   0.98        1000.0      v5p-64
# 26         256  1.00      24         2048   0.98           NaN     v6e-128
# 27         256  0.50      16         1024   0.98       -1000.0      v6e-16
# 28         256  0.30      16         1024   0.98          -2.0      v6e-64
# 29         256  0.50      16         1024   0.98          -2.0      v6e-64
# 30         256  1.00      16         1024   0.98       -1000.0      v6e-64
# 31         128  0.40      10          640   0.99           2.0       v6e-8
# 32         128  0.40      20         1536   0.99        1000.0       v6e-8
# 33         128  0.40      20         1536   0.99       -1000.0       v6e-8
#
#     tpu_count           tpu_zone  is_running
# 0           1         us-east1-d        True
# 1           1         us-east1-d        True
# 2           1         us-east1-d        True
# 3           1         us-east1-d        True
# 4           1     europe-west4-a        True
# 5           4     europe-west4-a        True
# 6           4     europe-west4-a        True
# 7           2     europe-west4-a        True
# 8           1      us-central1-a        True
# 9           1      us-central1-a        True
# 10          1      us-central1-a        True
# 11          1      us-central1-a        True
# 12          1         us-east5-a        True
# 13          1         us-east5-a        True
# 14          1         us-east5-a        True
# 15          1         us-east5-a        True
# 16          1         us-east5-a        True
# 17          1         us-east5-a        True
# 18          1         us-east5-a        True
# 19          1         us-east5-a        True
# 20          1         us-east5-a        True
# 21          1         us-east5-a        True
# 22          1         us-east5-a        True
# 23          1         us-east5-a        True
# 24          1         us-east5-a        True
# 25          1         us-east5-a        True
# 26          1         us-east5-b        True
# 27          4         us-east5-b        True
# 28          1         us-east5-b        True
# 29          1         us-east5-b        True
# 30          1         us-east5-b        True
# 31          4  asia-northeast1-b        True
# 32          4  asia-northeast1-b        True
# 33          4  asia-northeast1-b        True

# %%
hparams_by_bs = {
    8: ([0.05, 0.1, 0.2, 0.3], [0.99]),
    16: ([0.1, 0.2, 0.3, 0.5], [0.99]),
    32: ([0.1, 0.2, 0.3, 0.5], [0.99]),
    64: ([0.2, 0.3, 0.5, 1.0], [0.99]),
    128: ([0.3, 0.5, 1.0], [0.99]),
    256: ([0.3, 0.5, 1.0], [0.98]),
    512: ([0.3, 0.5, 1.0], [0.98]),
}
target_mixing_shifts = [-1000.0, -2.0, 0.0, 2.0, 1000.0]
target_sizes = [(8, 512), (12, 768), (16, 1024)]

rows = [
    {
        "batch_size": bs,
        "lr": lr,
        "mixing_shift": ms,
        "layers": l,
        "hidden_size": d,
        "beta2": b2,
    }
    for bs, (lrs, b2s) in hparams_by_bs.items() for lr in lrs for b2 in b2s
    for ms in target_mixing_shifts
    for l, d in target_sizes
]

# ---------------------------

hparams_by_bs = {
    8: ([0.2], [0.99]),
    16: ([0.2], [0.99]),
    32: ([0.25], [0.99]),
    64: ([0.35], [0.99]),
    128: ([0.4], [0.99]),
    256: ([0.5], [0.98]),
    512: ([0.6], [0.98]),
}
target_mixing_shifts = [-1000.0, -2.0, 0.0, 2.0, 1000.0]
target_sizes = [(10, 640), (20, 1536)]

rows += [
    {
        "batch_size": bs,
        "lr": lr,
        "mixing_shift": ms,
        "layers": l,
        "hidden_size": d,
        "beta2": b2,
    }
    for bs, (lrs, b2s) in hparams_by_bs.items() for lr in lrs for b2 in b2s
    for ms in target_mixing_shifts
    for l, d in target_sizes
]
len(rows)
# Out:
# 445

# %%
import tqdm.auto as tqdm

wandb_rows = []
needed_df = pd.DataFrame(rows)
needed_df["is_needed"] = True
for run in tqdm.tqdm(runs):
    cfg = run.config
    state = run.state
    wandb_rows.append({
        "batch_size": cfg.get("batch_size"),
        "lr": cfg.get("lr"),
        "mixing_shift": cfg.get("hybrid_mixing_shift"),
        "layers": cfg.get("num_layers"),
        "hidden_size": cfg.get("hidden_size"),
        "beta2": cfg.get("beta2"),
        "status": state,
        "wandb_id": run.id,
        "ray_id": cfg.get("ray_job_id"),
        "step": run.summary.get("_step"),
        "name": run.name,
        "tpu_version": cfg.get("tpu_version"),
        "tpu_zone": cfg.get("tpu_zone"),
        "tpu_count": cfg.get("tpu_pod_count"),
        "command": cfg.get("command"),
    })

wandb_df = pd.DataFrame(wandb_rows).dropna(how="any")
# Out:
#   0%|          | 0/510 [00:00<?, ?it/s]

# %%
existing_df = wandb_df.merge(running_df, how="outer", on=merge_keys, suffixes=("", "_running"))
existing_df.loc[existing_df["status"].isna(), "status"] = "pending"
existing_df.loc[existing_df["tpu_count"].isna(), "tpu_count"] = existing_df.loc[existing_df["tpu_count"].isna(), "tpu_count_running"].astype(int)
existing_df
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2    status  \
# 0           8.0  0.05       -1000.0     8.0        512.0   0.99  finished
# 1           8.0  0.05       -1000.0    12.0        768.0   0.99  finished
# 2           8.0  0.05       -1000.0    16.0       1024.0   0.99  finished
# 3           8.0  0.05          -2.0     8.0        512.0   0.99  finished
# 4           8.0  0.05          -2.0    12.0        768.0   0.99  finished
# ..          ...   ...           ...     ...          ...    ...       ...
# 457       512.0  2.00           0.0     8.0        512.0   0.98  finished
# 458       512.0  2.00           2.0     8.0        512.0   0.98  finished
# 459      1024.0  0.80           NaN    40.0       5120.0   0.95   pending
# 460      1024.0  1.00           0.0     8.0        512.0   0.97   crashed
# 461      1024.0  2.00           0.0     8.0        512.0   0.97   running
#
#      wandb_id    ray_id      step  \
# 0    41x399b0  14000000  100000.0
# 1    s0u7gktl  19000000  100000.0
# 2    aoycq16e  1e000000  100000.0
# 3    j9sznhsd  4a000000  100000.0
# 4    7nd2xgmu  4f000000  100000.0
# ..        ...       ...       ...
# 457  ngqox211  14000000  100000.0
# 458  clu5ynkz  1f000000  100000.0
# 459       NaN       NaN       NaN
# 460  mgywim12  29000000   21850.0
# 461  7uw3u08p  03000000   23550.0
#
#                                                   name tpu_version  \
# 0        gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 1      gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 2     gidd-L16-D1024-H16-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 3    gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_low_u...       v6e-8
# 4    gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_low...       v6e-8
# ..                                                 ...         ...
# 457  gidd-L8-D512-H8-N2048-bs=512-lr=2.0-noise_bala...      v5p-32
# 458  gidd-L8-D512-H8-N2048-bs=512-lr=2.0-noise_high...      v5p-32
# 459                                                NaN    v5p-1024
# 460  gidd-L8-D512-H8-N2048-bs=1024-lr=1.0-noise_bal...      v5p-64
# 461  gidd-L8-D512-H8-N2048-bs=1024-lr=2.0-noise_bal...     v6e-256
#
#            tpu_zone tpu_count  \
# 0    europe-west4-a         1
# 1    europe-west4-a         1
# 2    europe-west4-a         1
# 3        us-east5-b         1
# 4        us-east5-b         1
# ..              ...       ...
# 457      us-east5-a         1
# 458      us-east5-a         1
# 459      us-east5-a         1
# 460   us-central1-a         1
# 461      us-east1-d         1
#
#                                                command  tpu_count_running  \
# 0    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 1    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 2    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 3    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 4    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# ..                                                 ...                ...
# 457  main_ray.py --batch_size 512 --lr 2.0 --max_tr...                NaN
# 458  main_ray.py --batch_size 512 --lr 2.0 --max_tr...                NaN
# 459                                                NaN                1.0
# 460  main_ray.py --batch_size 1024 --lr 1.0 --max_t...                1.0
# 461  main_ray.py --batch_size 1024 --lr 2.0 --max_t...                1.0
#
#     is_running
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 457        NaN
# 458        NaN
# 459       True
# 460       True
# 461       True
#
# [462 rows x 17 columns]

# %%
df = existing_df.merge(needed_df, how="outer")
df.loc[:, "is_needed"] = df["is_needed"].fillna(False)
df["is_done"] = df["status"] == "finished"
df.loc[df["is_running"].isna(), "is_running"] = False
df = df.sort_values(["is_done", "is_running", "step"], ascending=[False, False, False])
df = df.drop_duplicates(subset=merge_keys, keep="first", inplace=False)
df.loc[(df["status"] == "crashed") & df["is_needed"] & (df["step"].isna() | (df["step"] < 100)), "status"] = "missing"
df.loc[df["is_needed"], "status"] = df.loc[df["is_needed"], "status"].fillna("missing")
# df.loc[~df["wandb_id"].isna(), "status"] = df.loc[~df["wandb_id"].isna(), "status"].fillna("N/A")
df.loc[df["command"].isna(), "command"] = df.loc[df["command"].isna()].apply(format_command, axis=1)
df
# Out:
# /tmp/ipykernel_1118431/1242863407.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[:, "is_needed"] = df["is_needed"].fillna(False)
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2    status  \
# 0           8.0  0.05       -1000.0     8.0        512.0   0.99  finished
# 1           8.0  0.05       -1000.0    12.0        768.0   0.99  finished
# 2           8.0  0.05       -1000.0    16.0       1024.0   0.99  finished
# 3           8.0  0.05          -2.0     8.0        512.0   0.99  finished
# 4           8.0  0.05          -2.0    12.0        768.0   0.99  finished
# ..          ...   ...           ...     ...          ...    ...       ...
# 497       512.0  1.00           0.0    16.0       1024.0   0.98   missing
# 499       512.0  1.00           2.0    12.0        768.0   0.98   missing
# 500       512.0  1.00           2.0    16.0       1024.0   0.98   missing
# 504       512.0  1.00        1000.0    12.0        768.0   0.98   missing
# 505       512.0  1.00        1000.0    16.0       1024.0   0.98   missing
#
#      wandb_id    ray_id      step  \
# 0    41x399b0  14000000  100000.0
# 1    s0u7gktl  19000000  100000.0
# 2    aoycq16e  1e000000  100000.0
# 3    j9sznhsd  4a000000  100000.0
# 4    7nd2xgmu  4f000000  100000.0
# ..        ...       ...       ...
# 497       NaN       NaN       NaN
# 499       NaN       NaN       NaN
# 500       NaN       NaN       NaN
# 504       NaN       NaN       NaN
# 505       NaN       NaN       NaN
#
#                                                   name tpu_version  \
# 0        gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 1      gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 2     gidd-L16-D1024-H16-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 3    gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_low_u...       v6e-8
# 4    gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_low...       v6e-8
# ..                                                 ...         ...
# 497                                                NaN         NaN
# 499                                                NaN         NaN
# 500                                                NaN         NaN
# 504                                                NaN         NaN
# 505                                                NaN         NaN
#
#            tpu_zone tpu_count  \
# 0    europe-west4-a         1
# 1    europe-west4-a         1
# 2    europe-west4-a         1
# 3        us-east5-b         1
# 4        us-east5-b         1
# ..              ...       ...
# 497             NaN       NaN
# 499             NaN       NaN
# 500             NaN       NaN
# 504             NaN       NaN
# 505             NaN       NaN
#
#                                                command  tpu_count_running  \
# 0    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 1    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 2    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 3    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# 4    main_ray.py --batch_size 8 --lr 0.05 --max_tra...                NaN
# ..                                                 ...                ...
# 497  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 499  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 500  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 504  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 505  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
#
#     is_running is_needed  is_done
# 0        False      True     True
# 1        False      True     True
# 2        False      True     True
# 3        False      True     True
# 4        False      True     True
# ..         ...       ...      ...
# 497      False      True    False
# 499      False      True    False
# 500      False      True    False
# 504      False      True    False
# 505      False      True    False
#
# [485 rows x 19 columns]

# %%
df["status"].value_counts()
# Out:
# status
# finished    361
# missing      53
# crashed      42
# running      26
# pending       3
# Name: count, dtype: int64

# %%
df.loc[df["is_running"]].groupby("tpu_zone").size()
# Out:
# tpu_zone
# asia-northeast1-b     3
# europe-west4-a        4
# us-central1-a         4
# us-east1-d            4
# us-east5-a           14
# us-east5-b            5
# dtype: int64

# %%
print(df.loc[df["is_running"]].groupby(["tpu_zone", "status"]).size())
# Out:
# tpu_zone           status
# asia-northeast1-b  running     3
# europe-west4-a     crashed     1
#                    running     3
# us-central1-a      crashed     2
#                    running     2
# us-east1-d         running     4
# us-east5-a         pending     2
#                    running    12
# us-east5-b         crashed     2
#                    pending     1
#                    running     2
# dtype: int64

# %%
print(df.loc[(df["status"] != "crashed") & (df["is_running"] == True)].groupby(["tpu_zone", "status"]).size())
# Out:
# tpu_zone           status
# asia-northeast1-b  running     3
# europe-west4-a     running     3
# us-central1-a      running     2
# us-east1-d         running     4
# us-east5-a         pending     2
#                    running    12
# us-east5-b         pending     1
#                    running     2
# dtype: int64

# %%
print(df.loc[(df["status"] == "crashed") & (df["is_running"] != True)].groupby(["tpu_zone", "status"]).size())
# Out:
# tpu_zone           status
# asia-northeast1-b  crashed     7
# europe-west4-a     crashed    14
# us-central1-a      crashed     1
# us-east5-b         crashed    15
# dtype: int64

# %%
df.loc[df["status"] == "running"]
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2   status  \
# 463       512.0  0.50          -2.0    12.0        768.0   0.98  running
# 467       512.0  0.50           0.0    12.0        768.0   0.98  running
# 391       256.0  0.30           2.0    12.0        768.0   0.98  running
# 399       256.0  0.50       -1000.0    12.0        768.0   0.98  running
# 465       512.0  0.50           0.0     8.0        512.0   0.95  running
# 460       512.0  0.50       -1000.0    16.0       1024.0   0.98  running
# 471       512.0  0.50           2.0    16.0       1024.0   0.98  running
# 459       512.0  0.50       -1000.0    12.0        768.0   0.98  running
# 474       512.0  0.50        1000.0    12.0        768.0   0.98  running
# 470       512.0  0.50           2.0    12.0        768.0   0.98  running
# 443       512.0  0.30       -1000.0     8.0        512.0   0.98  running
# 434       256.0  1.00           0.0    16.0       1024.0   0.98  running
# 464       512.0  0.50          -2.0    16.0       1024.0   0.98  running
# 468       512.0  0.50           0.0    16.0       1024.0   0.98  running
# 475       512.0  0.50        1000.0    16.0       1024.0   0.98  running
# 406       256.0  0.50          -2.0    16.0       1024.0   0.98  running
# 446       512.0  0.30          -2.0     8.0        512.0   0.98  running
# 400       256.0  0.50       -1000.0    16.0       1024.0   0.98  running
# 174        32.0  0.25           0.0    10.0        640.0   0.99  running
# 449       512.0  0.30           0.0     8.0        512.0   0.98  running
# 322       128.0  0.40        1000.0    10.0        640.0   0.99  running
# 323       128.0  0.40        1000.0    20.0       1536.0   0.99  running
# 514      1024.0  2.00           0.0     8.0        512.0   0.97  running
# 317       128.0  0.40          -2.0    20.0       1536.0   0.99  running
# 315       128.0  0.40       -1000.0    20.0       1536.0   0.99  running
# 320       128.0  0.40           2.0    10.0        640.0   0.99  running
#
#      wandb_id    ray_id     step  \
# 463  pzk26tpw  25000000  98250.0
# 467  6yccys5s  26000000  98250.0
# 391  iv2ypo5q  09000000  93850.0
# 399  tmvuv129  07000000  89150.0
# 465  bg12ue86  27000000  86550.0
# 460  tvmgz7z9  22000000  83650.0
# 471  7mpx66js  29000000  71650.0
# 459  13x51cgd  23000000  68950.0
# 474  g5cb0w76  2a000000  68850.0
# 470  n5j1z3dt  28000000  68700.0
# 443  7l9ucxgq  2e000000  67250.0
# 434  kxz584fi  02000000  60200.0
# 464  zmy8n3k4  24000000  53950.0
# 468  4c34t8lh  27000000  53950.0
# 475  vv9dhdcv  2b000000  53950.0
# 406  unfqsfzp  0a000000  53450.0
# 446  73vpj9t2  2b000000  48900.0
# 400  l57aw9ji  19000000  45300.0
# 174  aa895rqo  36000000  41950.0
# 449  pqsbrerv  2f000000  38000.0
# 322  jvs8uw3u  41000000  25750.0
# 323  drkxzsqt  20000000  25650.0
# 514  7uw3u08p  03000000  23550.0
# 317  jc5rh03c  42000000  18150.0
# 315  3indg57j  1e000000  17600.0
# 320  m96n5cvp  1d000000  17100.0
#
#                                                   name tpu_version  \
# 463  gidd-L12-D768-H12-N2048-bs=512-lr=0.5-noise_lo...      v5p-64
# 467  gidd-L12-D768-H12-N2048-bs=512-lr=0.5-noise_ba...      v5p-64
# 391  gidd-L12-D768-H12-N2048-bs=256-lr=0.3-noise_hi...      v6e-32
# 399   gidd-L12-D768-H12-N2048-bs=256-lr=0.5-noise_mask      v6e-32
# 465  gidd-L8-D512-H8-N2048-bs=512-lr=0.5-noise_bala...      v5p-32
# 460  gidd-L16-D1024-H16-N2048-bs=512-lr=0.5-noise_mask      v5p-64
# 471  gidd-L16-D1024-H16-N2048-bs=512-lr=0.5-noise_h...      v5p-64
# 459   gidd-L12-D768-H12-N2048-bs=512-lr=0.5-noise_mask      v5p-64
# 474  gidd-L12-D768-H12-N2048-bs=512-lr=0.5-noise_un...      v5p-64
# 470  gidd-L12-D768-H12-N2048-bs=512-lr=0.5-noise_hi...      v5p-64
# 443     gidd-L8-D512-H8-N2048-bs=512-lr=0.3-noise_mask      v5p-32
# 434  gidd-L16-D1024-H16-N2048-bs=256-lr=1.0-noise_b...      v6e-64
# 464  gidd-L16-D1024-H16-N2048-bs=512-lr=0.5-noise_l...      v5p-64
# 468  gidd-L16-D1024-H16-N2048-bs=512-lr=0.5-noise_b...      v5p-64
# 475  gidd-L16-D1024-H16-N2048-bs=512-lr=0.5-noise_u...      v5p-64
# 406  gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_l...      v6e-64
# 446  gidd-L8-D512-H8-N2048-bs=512-lr=0.3-noise_low_...      v5p-32
# 400  gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_mask      v6e-16
# 174     gidd-L10-D640-H10-bs=32-lr=0.25-noise_balanced       v6e-8
# 449  gidd-L8-D512-H8-N2048-bs=512-lr=0.3-noise_bala...      v5p-32
# 322      gidd-L10-D640-H10-bs=128-lr=0.4-noise_uniform       v6e-8
# 323     gidd-L20-D1536-H12-bs=128-lr=0.4-noise_uniform       v6e-8
# 514  gidd-L8-D512-H8-N2048-bs=1024-lr=2.0-noise_bal...     v6e-256
# 317  gidd-L20-D1536-H12-bs=128-lr=0.4-noise_low_uni...       v6e-8
# 315        gidd-L20-D1536-H12-bs=128-lr=0.4-noise_mask       v6e-8
# 320  gidd-L10-D640-H10-bs=128-lr=0.4-noise_high_uni...       v6e-8
#
#               tpu_zone tpu_count  \
# 463         us-east5-a         1
# 467         us-east5-a         1
# 391         us-east1-d         1
# 399         us-east1-d         1
# 465      us-central1-a         1
# 460         us-east5-a         1
# 471         us-east5-a         1
# 459         us-east5-a         1
# 474         us-east5-a         1
# 470         us-east5-a         1
# 443         us-east5-a         1
# 434         us-east1-d         1
# 464         us-east5-a         1
# 468         us-east5-a         1
# 475         us-east5-a         1
# 406         us-east5-b         1
# 446      us-central1-a         1
# 400         us-east5-b         4
# 174     europe-west4-a         2
# 449         us-east5-a         1
# 322     europe-west4-a         4
# 323  asia-northeast1-b         4
# 514         us-east1-d         1
# 317     europe-west4-a         4
# 315  asia-northeast1-b         4
# 320  asia-northeast1-b         4
#
#                                                command  tpu_count_running  \
# 463  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 467  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 391  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                1.0
# 399  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                1.0
# 465  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 460  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 471  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 459  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 474  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 470  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 443  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                1.0
# 434  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                1.0
# 464  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 468  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 475  main_ray.py --batch_size 512 --lr 0.5 --max_tr...                1.0
# 406  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                1.0
# 446  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                1.0
# 400  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                4.0
# 174  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                2.0
# 449  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                1.0
# 322  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                4.0
# 323  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                4.0
# 514  main_ray.py --batch_size 1024 --lr 2.0 --max_t...                1.0
# 317  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                4.0
# 315  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                4.0
# 320  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                4.0
#
#     is_running is_needed  is_done
# 463       True      True    False
# 467       True      True    False
# 391       True      True    False
# 399       True      True    False
# 465       True     False    False
# 460       True      True    False
# 471       True      True    False
# 459       True      True    False
# 474       True      True    False
# 470       True      True    False
# 443       True      True    False
# 434       True      True    False
# 464       True      True    False
# 468       True      True    False
# 475       True      True    False
# 406       True      True    False
# 446       True      True    False
# 400       True      True    False
# 174       True      True    False
# 449       True      True    False
# 322       True      True    False
# 323       True      True    False
# 514       True     False    False
# 317       True      True    False
# 315       True      True    False
# 320       True      True    False

# %%
df.loc[(df["status"] == "crashed") & (df["is_running"] != True)]
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2   status  \
# 170        32.0  0.25       -1000.0    10.0        640.0   0.99  crashed
# 254        64.0  0.30        1000.0    20.0       1536.0   0.99  crashed
# 243        64.0  0.30           0.0    20.0       1536.0   0.99  crashed
# 240        64.0  0.30           0.0    10.0        640.0   0.99  crashed
# 242        64.0  0.30           0.0    16.0       1024.0   0.99  crashed
# 303       128.0  0.30          -2.0    16.0       1024.0   0.99  crashed
# 331       128.0  0.50           0.0     8.0        512.0   0.99  crashed
# 379       256.0  0.30       -1000.0    12.0        768.0   0.98  crashed
# 356       128.0  1.00           2.0    16.0       1024.0   0.99  crashed
# 178        32.0  0.25        1000.0    10.0        640.0   0.99  crashed
# 501       512.0  1.00        1000.0     8.0        512.0   0.97  crashed
# 433       256.0  1.00           0.0    12.0        768.0   0.98  crashed
# 235        64.0  0.30          -2.0    10.0        640.0   0.99  crashed
# 179        32.0  0.25        1000.0    20.0       1536.0   0.99  crashed
# 267        64.0  0.50       -1000.0    16.0       1024.0   0.99  crashed
# 314       128.0  0.40       -1000.0    10.0        640.0   0.99  crashed
# 176        32.0  0.25           2.0    10.0        640.0   0.99  crashed
# 426       256.0  1.00       -1000.0    12.0        768.0   0.98  crashed
# 347       128.0  1.00          -2.0    12.0        768.0   0.99  crashed
# 184        32.0  0.30          -2.0    12.0        768.0   0.99  crashed
# 316       128.0  0.40          -2.0    10.0        640.0   0.99  crashed
# 318       128.0  0.40           0.0    10.0        640.0   0.99  crashed
# 387       256.0  0.30           0.0    12.0        768.0   0.98  crashed
# 171        32.0  0.25       -1000.0    20.0       1536.0   0.99  crashed
# 440       256.0  1.00        1000.0    12.0        768.0   0.98  crashed
# 412       256.0  0.50           0.0    16.0       1024.0   0.98  crashed
# 319       128.0  0.40           0.0    20.0       1536.0   0.99  crashed
# 394       256.0  0.30        1000.0    12.0        768.0   0.98  crashed
# 395       256.0  0.30        1000.0    16.0       1024.0   0.98  crashed
# 380       256.0  0.30       -1000.0    16.0       1024.0   0.98  crashed
# 238        64.0  0.30          -2.0    20.0       1536.0   0.99  crashed
# 392       256.0  0.30           2.0    16.0       1024.0   0.98  crashed
# 175        32.0  0.25           0.0    20.0       1536.0   0.99  crashed
# 251        64.0  0.30        1000.0    10.0        640.0   0.99  crashed
# 249        64.0  0.30           2.0    20.0       1536.0   0.99  crashed
# 431       256.0  1.00          -2.0    16.0       1024.0   0.98  crashed
# 321       128.0  0.40           2.0    20.0       1536.0   0.99  crashed
#
#      wandb_id    ray_id     step  \
# 170  g9kdbc98  35000000  94500.0
# 254  cl3rs8d7  1b000000  74450.0
# 243  o9g43r2z  1a000000  66900.0
# 240  yeoig5q7  15000000  54600.0
# 242  0ur979k3  21000000  52350.0
# 303  judac7vi  43000000  51100.0
# 331  l0ifyy46  11000000  47750.0
# 379  ws40hhw0  14000000  47600.0
# 356  v6fs2deb  3d000000  39350.0
# 178  qh7r3wcr  37000000  37550.0
# 501  l5u1x21u  25000000  36550.0
# 433  2k7qpx0g  29000000  35300.0
# 235  mgu7ufrv  38000000  35000.0
# 179  txtx7u9d  3c000000  32800.0
# 267  dytu5bm5  0e000000  31750.0
# 314  abk9gw7g  3f000000  29550.0
# 176  dr9d1qhm  13000000  28750.0
# 426  wpjh5pgt  09000000  26400.0
# 347  tct0kcxs  6f000000  26050.0
# 184  sym597eu  54000000  22700.0
# 316  x0b55y1u  1c000000  21500.0
# 318  r9xjwatd  40000000  20000.0
# 387  4yqkbuea  52000000  11350.0
# 171  2xcxblk6  3a000000  11300.0
# 440  d35zrazq  42000000  10950.0
# 412  yx9ds0os  28000000  10400.0
# 319  5jsh48sd  1f000000   8800.0
# 394  c10ctygv  39000000   8050.0
# 395  ojuz7tsk  27000000   7500.0
# 380  bnzcdk4l  26000000   7150.0
# 238  rcmycsp8  3d000000   7000.0
# 392  e3n1n2d2  1a000000   6350.0
# 175  yzf73zxt  3b000000   3950.0
# 251  cjp76b8r  16000000   2950.0
# 249  vxicz3g2  3e000000   2400.0
# 431  vflzemw2  1d000000   1300.0
# 321  4thvhht4  43000000    250.0
#
#                                                   name tpu_version  \
# 170         gidd-L10-D640-H10-bs=32-lr=0.25-noise_mask       v6e-8
# 254      gidd-L20-D1536-H12-bs=64-lr=0.3-noise_uniform       v6e-8
# 243     gidd-L20-D1536-H12-bs=64-lr=0.3-noise_balanced       v6e-8
# 240      gidd-L10-D640-H10-bs=64-lr=0.3-noise_balanced       v6e-8
# 242  gidd-L16-D1024-H16-N2048-bs=64-lr=0.3-noise_ba...      v6e-16
# 303  gidd-L16-D1024-H16-N2048-bs=128-lr=0.3-noise_l...      v6e-16
# 331  gidd-L8-D512-H8-N2048-bs=128-lr=0.5-noise_bala...      v6e-16
# 379   gidd-L12-D768-H12-N2048-bs=256-lr=0.3-noise_mask      v6e-32
# 356  gidd-L16-D1024-H16-N2048-bs=128-lr=1.0-noise_h...      v6e-16
# 178      gidd-L10-D640-H10-bs=32-lr=0.25-noise_uniform       v6e-8
# 501  gidd-L8-D512-H8-N2048-bs=512-lr=1.0-noise_unif...      v5p-32
# 433  gidd-L12-D768-H12-N2048-bs=256-lr=1.0-noise_ba...      v6e-32
# 235   gidd-L10-D640-H10-bs=64-lr=0.3-noise_low_uniform       v6e-8
# 179     gidd-L20-D1536-H12-bs=32-lr=0.25-noise_uniform       v6e-8
# 267   gidd-L16-D1024-H16-N2048-bs=64-lr=0.5-noise_mask      v6e-16
# 314         gidd-L10-D640-H10-bs=128-lr=0.4-noise_mask       v6e-8
# 176  gidd-L10-D640-H10-bs=32-lr=0.25-noise_high_uni...       v6e-8
# 426   gidd-L12-D768-H12-N2048-bs=256-lr=1.0-noise_mask      v6e-32
# 347  gidd-L12-D768-H12-N2048-bs=128-lr=1.0-noise_lo...      v6e-16
# 184  gidd-L12-D768-H12-N2048-bs=32-lr=0.3-noise_low...       v6e-8
# 316  gidd-L10-D640-H10-bs=128-lr=0.4-noise_low_uniform       v6e-8
# 318     gidd-L10-D640-H10-bs=128-lr=0.4-noise_balanced       v6e-8
# 387  gidd-L12-D768-H12-N2048-bs=256-lr=0.3-noise_ba...      v6e-32
# 171        gidd-L20-D1536-H12-bs=32-lr=0.25-noise_mask       v6e-8
# 440  gidd-L12-D768-H12-N2048-bs=256-lr=1.0-noise_un...      v6e-32
# 412  gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_b...      v6e-16
# 319    gidd-L20-D1536-H12-bs=128-lr=0.4-noise_balanced       v6e-8
# 394  gidd-L12-D768-H12-N2048-bs=256-lr=0.3-noise_un...      v6e-32
# 395  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_u...      v6e-16
# 380  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_mask      v6e-16
# 238  gidd-L20-D1536-H12-bs=64-lr=0.3-noise_low_uniform       v6e-8
# 392  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_h...      v6e-16
# 175    gidd-L20-D1536-H12-bs=32-lr=0.25-noise_balanced       v6e-8
# 251       gidd-L10-D640-H10-bs=64-lr=0.3-noise_uniform       v6e-8
# 249  gidd-L20-D1536-H12-bs=64-lr=0.3-noise_high_uni...       v6e-8
# 431  gidd-L16-D1024-H16-N2048-bs=256-lr=1.0-noise_l...      v6e-16
# 321  gidd-L20-D1536-H12-bs=128-lr=0.4-noise_high_un...       v6e-8
#
#               tpu_zone tpu_count  \
# 170     europe-west4-a         2
# 254  asia-northeast1-b         2
# 243  asia-northeast1-b         2
# 240  asia-northeast1-b         2
# 242         us-east5-b         1
# 303         us-east5-b         1
# 331         us-east5-b         1
# 379         us-east5-b         1
# 356         us-east5-b         1
# 178     europe-west4-a         2
# 501      us-central1-a         1
# 433         us-east5-b         1
# 235     europe-west4-a         2
# 179     europe-west4-a         2
# 267         us-east5-b         1
# 314     europe-west4-a         4
# 176  asia-northeast1-b         2
# 426         us-east5-b         1
# 347         us-east5-b         1
# 184         us-east5-b         1
# 316  asia-northeast1-b         4
# 318     europe-west4-a         4
# 387         us-east5-b         1
# 171     europe-west4-a         2
# 440         us-east5-b         1
# 412     europe-west4-a         4
# 319  asia-northeast1-b         4
# 394         us-east5-b         1
# 395     europe-west4-a         4
# 380     europe-west4-a         4
# 238     europe-west4-a         2
# 392         us-east5-b         4
# 175     europe-west4-a         2
# 251  asia-northeast1-b         2
# 249     europe-west4-a         2
# 431         us-east5-b         4
# 321     europe-west4-a         4
#
#                                                command  tpu_count_running  \
# 170  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 254  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 243  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 240  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 242  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 303  main_ray.py --batch_size 128 --lr 0.3 --max_tr...                NaN
# 331  main_ray.py --batch_size 128 --lr 0.5 --max_tr...                NaN
# 379  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 356  main_ray.py --batch_size 128 --lr 1.0 --max_tr...                NaN
# 178  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 501  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 433  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 235  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 179  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 267  main_ray.py --batch_size 64 --lr 0.5 --max_tra...                NaN
# 314  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                NaN
# 176  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 426  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 347  main_ray.py --batch_size 128 --lr 1.0 --max_tr...                NaN
# 184  main_ray.py --batch_size 32 --lr 0.3 --max_tra...                NaN
# 316  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                NaN
# 318  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                NaN
# 387  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 171  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 440  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 412  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 319  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                NaN
# 394  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 395  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 380  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 238  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 392  main_ray.py --batch_size 256 --lr 0.3 --max_tr...                NaN
# 175  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 251  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 249  main_ray.py --batch_size 64 --lr 0.3 --max_tra...                NaN
# 431  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 321  main_ray.py --batch_size 128 --lr 0.4 --max_tr...                NaN
#
#     is_running is_needed  is_done
# 170      False      True    False
# 254      False     False    False
# 243      False     False    False
# 240      False     False    False
# 242      False      True    False
# 303      False      True    False
# 331      False      True    False
# 379      False      True    False
# 356      False      True    False
# 178      False      True    False
# 501      False     False    False
# 433      False      True    False
# 235      False     False    False
# 179      False      True    False
# 267      False      True    False
# 314      False      True    False
# 176      False      True    False
# 426      False      True    False
# 347      False      True    False
# 184      False      True    False
# 316      False      True    False
# 318      False      True    False
# 387      False      True    False
# 171      False      True    False
# 440      False      True    False
# 412      False      True    False
# 319      False      True    False
# 394      False      True    False
# 395      False      True    False
# 380      False      True    False
# 238      False     False    False
# 392      False      True    False
# 175      False      True    False
# 251      False     False    False
# 249      False     False    False
# 431      False      True    False
# 321      False      True    False

# %%
df.loc[df["status"] == "missing"]
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2   status  \
# 173        32.0  0.25          -2.0    20.0       1536.0   0.99  missing
# 255        64.0  0.35       -1000.0    10.0        640.0   0.99  missing
# 256        64.0  0.35       -1000.0    20.0       1536.0   0.99  missing
# 257        64.0  0.35          -2.0    10.0        640.0   0.99  missing
# 258        64.0  0.35          -2.0    20.0       1536.0   0.99  missing
# 259        64.0  0.35           0.0    10.0        640.0   0.99  missing
# 260        64.0  0.35           0.0    20.0       1536.0   0.99  missing
# 261        64.0  0.35           2.0    10.0        640.0   0.99  missing
# 262        64.0  0.35           2.0    20.0       1536.0   0.99  missing
# 263        64.0  0.35        1000.0    10.0        640.0   0.99  missing
# 264        64.0  0.35        1000.0    20.0       1536.0   0.99  missing
# 397       256.0  0.50       -1000.0    10.0        640.0   0.98  missing
# 401       256.0  0.50       -1000.0    20.0       1536.0   0.98  missing
# 403       256.0  0.50          -2.0    10.0        640.0   0.98  missing
# 407       256.0  0.50          -2.0    20.0       1536.0   0.98  missing
# 409       256.0  0.50           0.0    10.0        640.0   0.98  missing
# 413       256.0  0.50           0.0    20.0       1536.0   0.98  missing
# 415       256.0  0.50           2.0    10.0        640.0   0.98  missing
# 417       256.0  0.50           2.0    16.0       1024.0   0.98  missing
# 418       256.0  0.50           2.0    20.0       1536.0   0.98  missing
# 420       256.0  0.50        1000.0    10.0        640.0   0.98  missing
# 424       256.0  0.50        1000.0    20.0       1536.0   0.98  missing
# 441       256.0  1.00        1000.0    16.0       1024.0   0.98  missing
# 444       512.0  0.30       -1000.0    12.0        768.0   0.98  missing
# 445       512.0  0.30       -1000.0    16.0       1024.0   0.98  missing
# 447       512.0  0.30          -2.0    12.0        768.0   0.98  missing
# 448       512.0  0.30          -2.0    16.0       1024.0   0.98  missing
# 450       512.0  0.30           0.0    12.0        768.0   0.98  missing
# 451       512.0  0.30           0.0    16.0       1024.0   0.98  missing
# 453       512.0  0.30           2.0    12.0        768.0   0.98  missing
# 454       512.0  0.30           2.0    16.0       1024.0   0.98  missing
# 456       512.0  0.30        1000.0    12.0        768.0   0.98  missing
# 457       512.0  0.30        1000.0    16.0       1024.0   0.98  missing
# 477       512.0  0.60       -1000.0    10.0        640.0   0.98  missing
# 478       512.0  0.60       -1000.0    20.0       1536.0   0.98  missing
# 479       512.0  0.60          -2.0    10.0        640.0   0.98  missing
# 480       512.0  0.60          -2.0    20.0       1536.0   0.98  missing
# 481       512.0  0.60           0.0    10.0        640.0   0.98  missing
# 482       512.0  0.60           0.0    20.0       1536.0   0.98  missing
# 483       512.0  0.60           2.0    10.0        640.0   0.98  missing
# 484       512.0  0.60           2.0    20.0       1536.0   0.98  missing
# 485       512.0  0.60        1000.0    10.0        640.0   0.98  missing
# 486       512.0  0.60        1000.0    20.0       1536.0   0.98  missing
# 488       512.0  1.00       -1000.0    12.0        768.0   0.98  missing
# 489       512.0  1.00       -1000.0    16.0       1024.0   0.98  missing
# 492       512.0  1.00          -2.0    12.0        768.0   0.98  missing
# 493       512.0  1.00          -2.0    16.0       1024.0   0.98  missing
# 496       512.0  1.00           0.0    12.0        768.0   0.98  missing
# 497       512.0  1.00           0.0    16.0       1024.0   0.98  missing
# 499       512.0  1.00           2.0    12.0        768.0   0.98  missing
# 500       512.0  1.00           2.0    16.0       1024.0   0.98  missing
# 504       512.0  1.00        1000.0    12.0        768.0   0.98  missing
# 505       512.0  1.00        1000.0    16.0       1024.0   0.98  missing
#
#     wandb_id ray_id  step name tpu_version tpu_zone tpu_count  \
# 173      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 255      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 256      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 257      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 258      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 259      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 260      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 261      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 262      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 263      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 264      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 397      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 401      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 403      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 407      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 409      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 413      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 415      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 417      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 418      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 420      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 424      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 441      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 444      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 445      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 447      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 448      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 450      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 451      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 453      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 454      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 456      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 457      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 477      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 478      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 479      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 480      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 481      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 482      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 483      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 484      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 485      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 486      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 488      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 489      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 492      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 493      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 496      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 497      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 499      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 500      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 504      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 505      NaN    NaN   NaN  NaN         NaN      NaN       NaN
#
#                                                command  tpu_count_running  \
# 173  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 255  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 256  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 257  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 258  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 259  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 260  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 261  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 262  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 263  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 264  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 397  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 401  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 403  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 407  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 409  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 413  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 415  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 417  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 418  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 420  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 424  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 441  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 444  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 445  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 447  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 448  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 450  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 451  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 453  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 454  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 456  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 457  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 477  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 478  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 479  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 480  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 481  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 482  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 483  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 484  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 485  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 486  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 488  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 489  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 492  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 493  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 496  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 497  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 499  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 500  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 504  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 505  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
#
#     is_running is_needed  is_done
# 173      False      True    False
# 255      False      True    False
# 256      False      True    False
# 257      False      True    False
# 258      False      True    False
# 259      False      True    False
# 260      False      True    False
# 261      False      True    False
# 262      False      True    False
# 263      False      True    False
# 264      False      True    False
# 397      False      True    False
# 401      False      True    False
# 403      False      True    False
# 407      False      True    False
# 409      False      True    False
# 413      False      True    False
# 415      False      True    False
# 417      False      True    False
# 418      False      True    False
# 420      False      True    False
# 424      False      True    False
# 441      False      True    False
# 444      False      True    False
# 445      False      True    False
# 447      False      True    False
# 448      False      True    False
# 450      False      True    False
# 451      False      True    False
# 453      False      True    False
# 454      False      True    False
# 456      False      True    False
# 457      False      True    False
# 477      False      True    False
# 478      False      True    False
# 479      False      True    False
# 480      False      True    False
# 481      False      True    False
# 482      False      True    False
# 483      False      True    False
# 484      False      True    False
# 485      False      True    False
# 486      False      True    False
# 488      False      True    False
# 489      False      True    False
# 492      False      True    False
# 493      False      True    False
# 496      False      True    False
# 497      False      True    False
# 499      False      True    False
# 500      False      True    False
# 504      False      True    False
# 505      False      True    False

# %%
print(df.loc[(df["status"] == "crashed") & (df["is_running"] != True)].groupby(["batch_size", "layers", "hidden_size"]).size())
# Out:
# batch_size  layers  hidden_size
# 32.0        10.0    640.0          3
#             12.0    768.0          1
#             20.0    1536.0         3
# 64.0        10.0    640.0          3
#             16.0    1024.0         2
#             20.0    1536.0         4
# 128.0       8.0     512.0          1
#             10.0    640.0          3
#             12.0    768.0          1
#             16.0    1024.0         2
#             20.0    1536.0         2
# 256.0       12.0    768.0          6
#             16.0    1024.0         5
# 512.0       8.0     512.0          1
# dtype: int64

# %%
print(df.loc[df["status"] == "missing"].groupby(["batch_size", "layers", "hidden_size"]).size())
# Out:
# batch_size  layers  hidden_size
# 32.0        20.0    1536.0          1
# 64.0        10.0    640.0           5
#             20.0    1536.0          5
# 256.0       10.0    640.0           5
#             16.0    1024.0          2
#             20.0    1536.0          5
# 512.0       10.0    640.0           5
#             12.0    768.0          10
#             16.0    1024.0         10
#             20.0    1536.0          5
# dtype: int64

# %%
df.loc[(df["status"] == "missing")]
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2   status  \
# 173        32.0  0.25          -2.0    20.0       1536.0   0.99  missing
# 255        64.0  0.35       -1000.0    10.0        640.0   0.99  missing
# 256        64.0  0.35       -1000.0    20.0       1536.0   0.99  missing
# 257        64.0  0.35          -2.0    10.0        640.0   0.99  missing
# 258        64.0  0.35          -2.0    20.0       1536.0   0.99  missing
# 259        64.0  0.35           0.0    10.0        640.0   0.99  missing
# 260        64.0  0.35           0.0    20.0       1536.0   0.99  missing
# 261        64.0  0.35           2.0    10.0        640.0   0.99  missing
# 262        64.0  0.35           2.0    20.0       1536.0   0.99  missing
# 263        64.0  0.35        1000.0    10.0        640.0   0.99  missing
# 264        64.0  0.35        1000.0    20.0       1536.0   0.99  missing
# 397       256.0  0.50       -1000.0    10.0        640.0   0.98  missing
# 401       256.0  0.50       -1000.0    20.0       1536.0   0.98  missing
# 403       256.0  0.50          -2.0    10.0        640.0   0.98  missing
# 407       256.0  0.50          -2.0    20.0       1536.0   0.98  missing
# 409       256.0  0.50           0.0    10.0        640.0   0.98  missing
# 413       256.0  0.50           0.0    20.0       1536.0   0.98  missing
# 415       256.0  0.50           2.0    10.0        640.0   0.98  missing
# 417       256.0  0.50           2.0    16.0       1024.0   0.98  missing
# 418       256.0  0.50           2.0    20.0       1536.0   0.98  missing
# 420       256.0  0.50        1000.0    10.0        640.0   0.98  missing
# 424       256.0  0.50        1000.0    20.0       1536.0   0.98  missing
# 441       256.0  1.00        1000.0    16.0       1024.0   0.98  missing
# 444       512.0  0.30       -1000.0    12.0        768.0   0.98  missing
# 445       512.0  0.30       -1000.0    16.0       1024.0   0.98  missing
# 447       512.0  0.30          -2.0    12.0        768.0   0.98  missing
# 448       512.0  0.30          -2.0    16.0       1024.0   0.98  missing
# 450       512.0  0.30           0.0    12.0        768.0   0.98  missing
# 451       512.0  0.30           0.0    16.0       1024.0   0.98  missing
# 453       512.0  0.30           2.0    12.0        768.0   0.98  missing
# 454       512.0  0.30           2.0    16.0       1024.0   0.98  missing
# 456       512.0  0.30        1000.0    12.0        768.0   0.98  missing
# 457       512.0  0.30        1000.0    16.0       1024.0   0.98  missing
# 477       512.0  0.60       -1000.0    10.0        640.0   0.98  missing
# 478       512.0  0.60       -1000.0    20.0       1536.0   0.98  missing
# 479       512.0  0.60          -2.0    10.0        640.0   0.98  missing
# 480       512.0  0.60          -2.0    20.0       1536.0   0.98  missing
# 481       512.0  0.60           0.0    10.0        640.0   0.98  missing
# 482       512.0  0.60           0.0    20.0       1536.0   0.98  missing
# 483       512.0  0.60           2.0    10.0        640.0   0.98  missing
# 484       512.0  0.60           2.0    20.0       1536.0   0.98  missing
# 485       512.0  0.60        1000.0    10.0        640.0   0.98  missing
# 486       512.0  0.60        1000.0    20.0       1536.0   0.98  missing
# 488       512.0  1.00       -1000.0    12.0        768.0   0.98  missing
# 489       512.0  1.00       -1000.0    16.0       1024.0   0.98  missing
# 492       512.0  1.00          -2.0    12.0        768.0   0.98  missing
# 493       512.0  1.00          -2.0    16.0       1024.0   0.98  missing
# 496       512.0  1.00           0.0    12.0        768.0   0.98  missing
# 497       512.0  1.00           0.0    16.0       1024.0   0.98  missing
# 499       512.0  1.00           2.0    12.0        768.0   0.98  missing
# 500       512.0  1.00           2.0    16.0       1024.0   0.98  missing
# 504       512.0  1.00        1000.0    12.0        768.0   0.98  missing
# 505       512.0  1.00        1000.0    16.0       1024.0   0.98  missing
#
#     wandb_id ray_id  step name tpu_version tpu_zone tpu_count  \
# 173      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 255      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 256      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 257      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 258      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 259      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 260      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 261      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 262      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 263      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 264      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 397      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 401      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 403      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 407      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 409      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 413      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 415      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 417      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 418      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 420      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 424      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 441      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 444      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 445      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 447      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 448      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 450      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 451      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 453      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 454      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 456      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 457      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 477      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 478      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 479      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 480      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 481      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 482      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 483      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 484      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 485      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 486      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 488      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 489      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 492      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 493      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 496      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 497      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 499      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 500      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 504      NaN    NaN   NaN  NaN         NaN      NaN       NaN
# 505      NaN    NaN   NaN  NaN         NaN      NaN       NaN
#
#                                                command  tpu_count_running  \
# 173  main_ray.py --batch_size 32 --lr 0.25 --max_tr...                NaN
# 255  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 256  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 257  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 258  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 259  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 260  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 261  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 262  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 263  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 264  main_ray.py --batch_size 64 --lr 0.35 --max_tr...                NaN
# 397  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 401  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 403  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 407  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 409  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 413  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 415  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 417  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 418  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 420  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 424  main_ray.py --batch_size 256 --lr 0.5 --max_tr...                NaN
# 441  main_ray.py --batch_size 256 --lr 1.0 --max_tr...                NaN
# 444  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 445  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 447  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 448  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 450  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 451  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 453  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 454  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 456  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 457  main_ray.py --batch_size 512 --lr 0.3 --max_tr...                NaN
# 477  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 478  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 479  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 480  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 481  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 482  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 483  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 484  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 485  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 486  main_ray.py --batch_size 512 --lr 0.6 --max_tr...                NaN
# 488  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 489  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 492  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 493  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 496  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 497  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 499  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 500  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 504  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
# 505  main_ray.py --batch_size 512 --lr 1.0 --max_tr...                NaN
#
#     is_running is_needed  is_done
# 173      False      True    False
# 255      False      True    False
# 256      False      True    False
# 257      False      True    False
# 258      False      True    False
# 259      False      True    False
# 260      False      True    False
# 261      False      True    False
# 262      False      True    False
# 263      False      True    False
# 264      False      True    False
# 397      False      True    False
# 401      False      True    False
# 403      False      True    False
# 407      False      True    False
# 409      False      True    False
# 413      False      True    False
# 415      False      True    False
# 417      False      True    False
# 418      False      True    False
# 420      False      True    False
# 424      False      True    False
# 441      False      True    False
# 444      False      True    False
# 445      False      True    False
# 447      False      True    False
# 448      False      True    False
# 450      False      True    False
# 451      False      True    False
# 453      False      True    False
# 454      False      True    False
# 456      False      True    False
# 457      False      True    False
# 477      False      True    False
# 478      False      True    False
# 479      False      True    False
# 480      False      True    False
# 481      False      True    False
# 482      False      True    False
# 483      False      True    False
# 484      False      True    False
# 485      False      True    False
# 486      False      True    False
# 488      False      True    False
# 489      False      True    False
# 492      False      True    False
# 493      False      True    False
# 496      False      True    False
# 497      False      True    False
# 499      False      True    False
# 500      False      True    False
# 504      False      True    False
# 505      False      True    False

# %%
# print("\n".join(df.loc[(df["status"] == "missing") & (df["batch_size"] == 256)]["command"].values))
print("\n".join(df.loc[(df["status"] == "missing") & (df["batch_size"] == 512) & (df["layers"] > 8)].sort_values("lr")["command"].values))
# Out:
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l12_d768,noise_mask
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l16_d1024,noise_mask
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l12_d768,noise_low_uniform
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l16_d1024,noise_low_uniform
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l12_d768,noise_balanced
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l16_d1024,noise_balanced
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l12_d768,noise_high_uniform
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l16_d1024,noise_high_uniform
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l12_d768,noise_uniform
# main_ray.py --batch_size 512 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l16_d1024,noise_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.6-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12.0 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.6-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.6-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12.0 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.6-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.6-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12.0 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.6-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.6-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12.0 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.6-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.6-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# main_ray.py --batch_size 512 --lr 0.6 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12.0 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.6-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l12_d768,noise_mask
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l16_d1024,noise_mask
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l12_d768,noise_low_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l16_d1024,noise_low_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l12_d768,noise_balanced
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l16_d1024,noise_balanced
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l12_d768,noise_high_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l16_d1024,noise_high_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l12_d768,noise_uniform
# main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l16_d1024,noise_uniform

# %%
scaffold = """ray job submit --no-wait --address "{address}" --working-dir . --runtime-env-json='{{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}}' -- TPU_VERSION={tpu_version} TPU_POD_COUNT={tpu_count} python"""

zone_to_address = {
    "asia-northeast1-b": "$RAY_ASIA_NORTHEAST1_B",
    "europe-west4-a": "$RAY_EU_WEST4_A",
    "us-central1-a": "$RAY_US_CENTRAL1_A",
    "us-east1-d": "$RAY_US_EAST1_D",
    "us-east5-a": "$RAY_US_EAST5_A",
    "us-east5-b": "$RAY_US_EAST5_B",
}

def format_resume_command(row):
    base_cmd = row["command"]
    wandb_id = row["wandb_id"]
    tpu_zone = row["tpu_zone"]
    tpu_version = row["tpu_version"]
    tpu_count = row["tpu_count"]
    if "--resume_wandb_id" not in base_cmd and not pd.isna(wandb_id):
        base_cmd = f"{base_cmd} --resume_wandb_id {wandb_id}"
    address = zone_to_address.get(tpu_zone, "$RAY_US_EAST1_D")
    return scaffold.format(address=address, tpu_version=tpu_version, tpu_count=tpu_count) + " " + base_cmd.strip()

commands = df.loc[(df["status"] == "crashed") & (df["is_running"] != True) & (df["tpu_zone"] != "us-east5-b")].apply(format_resume_command, axis=1)

with open("resume_commands.txt", "w") as f:
    f.write("\n".join(commands.values))
print("\n".join(commands.values))
# Out:
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=32-lr=0.25-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags scaling_laws,l10_d640,noise_mask --resume_wandb_id g9kdbc98
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=64-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags scaling_laws,l20_d1536,noise_uniform --resume_wandb_id cl3rs8d7
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=64-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags scaling_laws,l20_d1536,noise_balanced --resume_wandb_id o9g43r2z
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=64-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags scaling_laws,l10_d640,noise_balanced --resume_wandb_id yeoig5q7
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=32-lr=0.25-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags scaling_laws,l10_d640,noise_uniform --resume_wandb_id qh7r3wcr
# ray job submit --no-wait --address "$RAY_US_CENTRAL1_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-32 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 100000 --num_layers 8 --hidden_size 512 --num_attn_heads 8 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.97 --no-break_on_nan --wandb_name gidd-L8-D512-H8-N2048-bs=512-lr=1.0-noise_uniform-b2=0.97 --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l8_d512,noise_uniform --resume_wandb_id l5u1x21u
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=64-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags scaling_laws,l10_d640,noise_low_uniform --resume_wandb_id mgu7ufrv
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=32-lr=0.25-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags scaling_laws,l20_d1536,noise_uniform --resume_wandb_id txtx7u9d
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=4 python main_ray.py --batch_size 128 --lr 0.4 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=128-lr=0.4-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags scaling_laws,l10_d640,noise_mask --resume_wandb_id abk9gw7g
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=32-lr=0.25-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags scaling_laws,l10_d640,noise_high_uniform --resume_wandb_id dr9d1qhm
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=4 python main_ray.py --batch_size 128 --lr 0.4 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=128-lr=0.4-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags scaling_laws,l10_d640,noise_low_uniform --resume_wandb_id x0b55y1u
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=4 python main_ray.py --batch_size 128 --lr 0.4 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=128-lr=0.4-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags scaling_laws,l10_d640,noise_balanced --resume_wandb_id r9xjwatd
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=32-lr=0.25-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags scaling_laws,l20_d1536,noise_mask --resume_wandb_id 2xcxblk6
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-16 TPU_POD_COUNT=4 python main_ray.py --batch_size 256 --lr 0.5 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l16_d1024,noise_balanced --resume_wandb_id yx9ds0os
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=4 python main_ray.py --batch_size 128 --lr 0.4 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=128-lr=0.4-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags scaling_laws,l20_d1536,noise_balanced --resume_wandb_id 5jsh48sd
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-16 TPU_POD_COUNT=4 python main_ray.py --batch_size 256 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l16_d1024,noise_uniform --resume_wandb_id ojuz7tsk
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-16 TPU_POD_COUNT=4 python main_ray.py --batch_size 256 --lr 0.3 --max_training_steps 100000 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l16_d1024,noise_mask --resume_wandb_id bnzcdk4l
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=64-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags scaling_laws,l20_d1536,noise_low_uniform --resume_wandb_id rcmycsp8
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 32 --lr 0.25 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=32-lr=0.25-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags scaling_laws,l20_d1536,noise_balanced --resume_wandb_id yzf73zxt
# ray job submit --no-wait --address "$RAY_ASIA_NORTHEAST1_B" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-bs=64-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags scaling_laws,l10_d640,noise_uniform --resume_wandb_id cjp76b8r
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=2 python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=64-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags scaling_laws,l20_d1536,noise_high_uniform --resume_wandb_id vxicz3g2
# ray job submit --no-wait --address "$RAY_EU_WEST4_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v6e-8 TPU_POD_COUNT=4 python main_ray.py --batch_size 128 --lr 0.4 --max_training_steps 100000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H12-bs=128-lr=0.4-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags scaling_laws,l20_d1536,noise_high_uniform --resume_wandb_id 4thvhht4
